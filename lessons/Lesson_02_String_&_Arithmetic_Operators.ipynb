# %% [markdown]
# # Strings & Arithmetic Operators

# %%
name1= "abbas"
name2= "aslam"
print(name1, name2)
# Out:
# abbas aslam

# %%
print(f"My name is {name1}", "{name1}")
# Out:
# My name is abbas {name1}

# %%
print("My name is Abbas.\nI am a Python developer.\nI study in GIAIC")
# Out:
# My name is Abbas.
# I am a Python developer.
# I study in GIAIC

# %%
print("""My name is Abbas.
I am a Python developer.
I study in GIAIC""") # Python Docstring
# Out:
# My name is Abbas.
# I am a Python developer.
# I study in GIAIC

# %%
# Assignment 1
to_name="Aslam"
from_name="Abbas Asad"
coupon_code="#725362"

email= f"""Hi {to_name}!
You got a free coupon code {coupon_code}.

Best Regards,
{from_name}"""

print(email)
# Out:
# Hi Aslam!
# You got a free coupon code #725362.
#
# Best Regards,
# Abbas Asad

# %%
number=15
statement= number%2==0

print(f"15 is an even number. This statement is {statement}")
# You can use modulus to check odd and even numbers
# Out:
# 15 is an even number. This statement is False

# %%
# Assignment 2
faculty_members=12
staff_members=4
student_members=100
absent_members=15
total_people_attending_event= (faculty_members + staff_members + student_members) - absent_members

per_person_rabri_in_gram=250
total_rabri_required_for_event_in_gram= per_person_rabri_in_gram * total_people_attending_event
total_rabri_required_for_event_in_kilo_gram= total_rabri_required_for_event_in_gram // 1000  # double slash to avoid decimals

print(f"""Total number of people attending the event is: {total_people_attending_event}
Amount of Rabri overall in grams is: {total_rabri_required_for_event_in_gram}g
Amount of Rabri overall in kilo grams is: {total_rabri_required_for_event_in_kilo_gram}kg
""")
# Out:
# Total number of people attending the event is: 101
# Amount of Rabri overall in grams is: 25250g
# Amount of Rabri overall in kilo grams is: 25kg
