# %% [markdown]
# # Object Oriented Programming with 21 assignments

# %% [markdown]
# # 1. Using self
# Assignment:
# Create a class Student with attributes name and marks. Use the self keyword to initialize these values via a constructor. Add a method display() that prints student details.

# %%
class Student:
  def __init__(self, name, marks):
    self.name = name
    self.marks = marks

  def display(self):
    print(f"Student Name: {self.name}, Marks: {self.marks}")

student_1 = Student(name= "Abbas", marks= 95)
student_2 = Student(name= "Assad", marks= 98)

student_1.display()
student_2.display()
# Out:
# Student Name: Abbas, Marks: 95
# Student Name: Assad, Marks: 98

# %% [markdown]
# # 2. Using cls
# Assignment:
# Create a class Counter that keeps track of how many objects have been created. Use a class variable and a class method with cls to manage and display the count.

# %%
class Counter:
  count = 0

  def __init__(self):
    Counter.count += 1

  @classmethod
  def display_count(cls):
    print("Number of objects created:", cls.count)

ins_1 = Counter()
ins_2 = Counter()
ins_3 = Counter()
ins_4 = Counter()

Counter.display_count()
# Out:
# Number of objects created: 4

# %% [markdown]
# # 3. Public Variables and Methods
# Assignment:
# Create a class Car with a public variable brand and a public method start(). Instantiate the class and access both from outside the class.

# %%
class Car:
  def __init__(self, brand):
    self.brand = brand

  def start(self):
    print("Car starts!")

car_1 = Car(brand= "Corolla")

print("Brand:", car_1.brand)
car_1.start()
# Out:
# Brand: Corolla
# Car starts!

# %% [markdown]
# # 4. Class Variables and Class Methods
# Assignment:
# Create a class Bank with a class variable bank_name. Add a class method change_bank_name(cls, name) that allows changing the bank name. Show that it affects all instances.

# %%
class Bank:
  bank_name = "Default Name"

  @classmethod
  def change_bank_name(cls, name):
    cls.bank_name = name
    print(cls.bank_name)

bank_1 = Bank()
bank_2 = Bank()

print("Bank name:", bank_1.bank_name)
print("Bank name:", bank_2.bank_name)

Bank.change_bank_name("Luxe Bank")

print("Bank name:", bank_1.bank_name)
print("Bank name:", bank_2.bank_name)
# Out:
# Bank name: Default Name
# Bank name: Default Name
# Luxe Bank
# Bank name: Luxe Bank
# Bank name: Luxe Bank

# %% [markdown]
# # 5. Static Variables and Static Methods
# Assignment:
# Create a class MathUtils with a static method add(a, b) that returns the sum. No class or instance variables should be used.

# %%
class MathUtils:

  @staticmethod
  def add(a, b):
    return a + b

MathUtils.add(3,4)
# Out:
# 7

# %% [markdown]
# # 6. Constructors and Destructors
# Assignment:
# Create a class Logger that prints a message when an object is created (constructor) and another message when it is destroyed (destructor).

# %%
class Logger:

  def __init__(self):
    print("Object is created")

  def __del__(self):
    print("Object is destructed")

print("---Creation---\n")

logger_1 = Logger()
logger_2 = Logger()

print("\n---Destruction---\n")

del logger_1
del logger_2
# Out:
# ---Creation---
#
# Object is created
# Object is created
#
# ---Destruction---
#
# Object is destructed
# Object is destructed

# %% [markdown]
# # 7. Access Modifiers: Public, Private, and Protected
# Assignment:
# Create a class Employee with:
#
# a public variable name,
#
# a protected variable _salary, and
#
# a private variable __ssn.
#
# Try accessing all three variables from an object of the class and document what happens.

# %%
class Employee:
  def __init__(self, name, salary, ssn):
    self.name = name
    self._salary = salary
    self.__ssn = ssn

emp_1 = Employee("Abbas", 250000, 86758)

print("Name:", emp_1.name)
print("Salary:", emp_1._salary) # we shouldn't
# print("SSN:", emp_1.__ssn) # uncomment to see error

summary_of_accessing_unpublic_variables = """
First when I wrote dot after the instance of Employee so I got only one suggestion
which already demonstrated that python is treating other variables as unpublic.
Later, when I tried to access other variables so I easily accessed
protected variable and couldn't access private variable.

The reason behind this that python interpreter allows you to access protected variable
is that python thinks that you are an adult you will definitely follow rules but technically it should not be accesssed
However, Python performs name mangling to make it harder to access private variable from outside the class
Note:You can use getter and setter methods if accessing or modifying private is crucial

So, In short we can't access private only outside the class,
we shouldn't access protected and privated outside the class
"""
# Out:
# Name: Abbas
# Salary: 250000

# %% [markdown]
# # 8. The super() Function
# Assignment:
# Create a class Person with a constructor that sets the name. Inherit a class Teacher from it, add a subject field, and use super() to call the base class constructor.

# %%
class Person:
  def __init__(self, name):
    self.name = name

class Teacher(Person):
  def __init__(self, name, subject):
    super().__init__(name)
    self.subject = subject

teacher_1 = Teacher("Abbas", "Agentic AI")

print("Teacher Name:", teacher_1.name)
print("Subject:", teacher_1.subject)
# Out:
# Teacher Name: Abbas
# Subject: Agentic AI

# %% [markdown]
# # 9. Abstract Classes and Methods
# Assignment:
# Use the abc module to create an abstract class Shape with an abstract method area(). Inherit a class Rectangle that implements area().

# %%
from abc import ABC as abstractclass, abstractmethod
import math

class Shape(abstractclass):
  @abstractmethod
  def area(self):
    pass

class Rectangle(Shape):
  def __init__(self, length, width):
    self.length = length
    self.width = width

  def area(self):
    return self.length * self.width

# Additional
class Circle(Shape):
  def __init__(self, diameter):
    self.diameter = diameter

  def area(self):
    return math.pi * (self.diameter / 2) ** 2

rectangle: Rectangle = Rectangle(5, 7)
circle: Circle = Circle(5)

print(rectangle.area())
print(circle.area())
# Out:
# 35
# 19.634954084936208

# %% [markdown]
# # 10. Instance Methods
# Assignment:
# Create a class Dog with instance variables name and breed. Add an instance method bark() that prints a message including the dog's name.

# %%
class Dog:
  def __init__(self, name, breed):
    self.name = name
    self.breed = breed

  def bark(self):
    print(f"{self.name} barks!")

dog_1 = Dog("Tommy", "Labrador")
dog_2 = Dog("Bruno", "German Shepherd")

print("Name:", dog_1.name)
print("Breed:", dog_1.breed)
dog_1.bark()

print("\nName:", dog_2.name)
print("Breed:", dog_2.breed)
dog_2.bark()
# Out:
# Name: Tommy
# Breed: Labrador
# Tommy barks!
#
# Name: Bruno
# Breed: German Shepherd
# Bruno barks!

# %% [markdown]
# # 11. Class Methods
# Assignment:
# Create a class Book with a class variable total_books. Add a class method increment_book_count() to increase the count when a new book is added.

# %%
class Book:
  total_books = 0

  def __init__(self):
    Book.increment_book_count()

  @classmethod
  def increment_book_count(cls):
    cls.total_books += 1

  @classmethod
  def show_total_books(cls):
    print(f"Total books: {cls.total_books}")

book_1 = Book()
book_2 = Book()
book_3 = Book()

Book.show_total_books()
# Out:
# Total books: 3

# %% [markdown]
# # 12. Static Methods
# Assignment:
# Create a class TemperatureConverter with a static method celsius_to_fahrenheit(c) that returns the Fahrenheit value.

# %%
class TemperatureConverter:
  @staticmethod
  def celsius_to_fahrenheit(c):
    return (c * 9/5) + 32

TemperatureConverter.celsius_to_fahrenheit(2)
# Out:
# 35.6

# %% [markdown]
# # 13. Composition
# Assignment:
# Create a class Engine and a class Car. Use composition by passing an Engine object to the Car class during initialization. Access a method of the Engine class via the Car class.

# %%
class Engine:
  def start(self):
    return "Engine starts"

  def stop(self):
    return "Engine stops"

class Car:
  def __init__(self):
    self.engine = Engine()

  def start(self):
    self.engine.start()
    return "Car starts"

  def stop(self):
    self.engine.stop()
    return "Car stops"

car_1: Car = Car()

print(car_1.start())
print(car_1.stop())
# Out:
# Car starts
# Car stops

# %% [markdown]
# # 14. Aggregation
# Assignment:
# Create a class Department and a class Employee. Use aggregation by having a Department object store a reference to an Employee object that exists independently of it.

# %%
class Employee:
    def __init__(self, name):
        self.name = name

class Department:
    def __init__(self, name, employee):
        self.name = name
        self.employee = employee

emp_1 = Employee("Abbas")
dept_1 = Department("Agentic AI", emp_1)

emp_2 = Employee("Qasim")
dept_2 = Department("Generative AI", emp_2)

print(dept_1.employee.name)
print(dept_1.name)

print(dept_2.employee.name)
print(dept_2.name)
# Out:
# Abbas
# Agentic AI
# Qasim
# Generative AI

# %% [markdown]
# # 15. Method Resolution Order (MRO) and Diamond Inheritance
# Assignment:
# Create four classes:
#
# A with a method show(),
#
# B and C that inherit from A and override show(),
#
# D that inherits from both B and C.
#
# Create an object of D and call show() to observe MRO.

# %%
class A:
  def show(self):
    return "Show A"

class B(A):
  def show(self):
    return "Show B"

class C(A):
  def show(self):
    return "Show C"

class D(B, C):
  pass

d = D()

print(D.mro())
print(d.show())
# Out:
# [<class '__main__.D'>, <class '__main__.B'>, <class '__main__.C'>, <class '__main__.A'>, <class 'object'>]
# Show B

# %% [markdown]
# # 16. Function Decorators
# Assignment:
# Write a decorator function log_function_call that prints "Function is being called" before a function executes. Apply it to a function say_hello().

# %%
def log_function_call(func):
  def wrapper():
    print("Function is being called")
    return func()
  return wrapper

@log_function_call
def say_hello():
  print("hello")

@log_function_call
def say_goodbye():
  print("say_goodbye")

say_hello()
say_goodbye()
# Out:
# Function is being called
# hello
# Function is being called
# say_goodbye

# %% [markdown]
# # 17. Class Decorators
# Assignment:
# Create a class decorator add_greeting that modifies a class to add a greet() method returning "Hello from Decorator!". Apply it to a class Person.

# %%
def add_greeting(cls):
  def greet(self):
    return "Hello from Decorator!"
  cls.greet = greet
  return cls

@add_greeting
class Person:
  def __init__(self, name):
    self.name = name

person_1 = Person("Abbas")
person_1.greet()
# Out:
# 'Hello from Decorator!'

# %% [markdown]
# # 18. Property Decorators: @property, @setter, and @deleter
# Assignment:
# Create a class Product with a private attribute _price. Use @property to get the price, @price.setter to update it, and @price.deleter to delete it.

# %%
class Product:
  def __init__(self, name, price):
    self.name = name
    self._price = price

  @property           # this will make price read only
  def price(self):
      return self._price

  @price.setter       # this will let you update value
  def price(self, new_price):
      self._price = new_price

  @price.deleter      # this will delete value
  def price(self):
      del self._price

product_1: Product = Product("Perfume", 900)
print(product_1.price)

del product_1.price
# print(product_1.price)   # got error because attribute is deleted
# Out:
# 900

# %% [markdown]
# # 19. callable() and __call__()
#
#
#
#
# Assignment:
# Create a class Multiplier with an __init__() to set a factor. Define a __call__() method that multiplies an input by the factor. Test it with callable() and by calling the object like a function.

# %%
class Multiplier:
  def __init__(self, factor):
    self.factor = factor

  def __call__(self, number):
    return self.factor * number

multiply_by_5 = Multiplier(5)

print(callable(multiply_by_5))
print(multiply_by_5(7))

# Additional
class Power:
  def __init__(self, factor):
    self.factor = factor

  def __call__(self, number):
    return number ** self.factor

square = Power(2)
cube = Power(3)

print(square(2))
print(cube(2))
# Out:
# True
# 35
# 4
# 8

# %% [markdown]
# # 20. Creating a Custom Exception
# Assignment:
# Create a custom exception InvalidAgeError. Write a function check_age(age) that raises this exception if age < 18. Handle it with try...except.

# %%
class InvalidAgeError(Exception):
  pass

def check_age(age):
  if age < 18:
    raise InvalidAgeError("Invalid age")
  else:
    print("Valid age")

try:
  check_age(17)
except InvalidAgeError as e:
  print(e)
# Out:
# Invalid age

# %% [markdown]
# # 21. Make a Custom Class Iterable
# Assignment:
# Create a class Countdown that takes a start number. Implement __iter__() and __next__() to make the object iterable in a for-loop, counting down to 0.

# %%
from collections.abc import Iterable, Iterator

class Countdown(Iterable):
  def __init__(self, start_num):
    self.start_num = start_num

  def __iter__(self):
    return self

  def __next__(self):
    if self.start_num < 0:
        raise StopIteration
    value = self.start_num
    self.start_num -= 1
    return value

for num in Countdown(5):
  print(num)
# Out:
# 5
# 4
# 3
# 2
# 1
# 0
